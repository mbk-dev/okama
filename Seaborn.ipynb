# %%
import seaborn as sns
from okama.assets import AssetList

# %%
y = AssetList(symbols=['SPY.US', 'GLD.US', '0890-94127385.RUFUND', '0165-70287767.RUFUND'], curr='RUB')

# %%
sns.heatmap(y.ror.corr(), annot=True)

# %%
sns.pairplot(y.ror)
