# %%
from pathlib import Path
import warnings

warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.image as image
import matplotlib.dates as mdates

plt.rcParams["figure.figsize"] = [12.0, 6.0]

import okama as ok

pd.options.display.float_format = "{:,.5f}".format
np.set_printoptions(precision=5)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ok.__version__
# Out:
# '1.4.4'

# %% [markdown]
# ## List Maker (Parallel)

# %%
from okama.common import make_asset_list

ls = ['SPY.US', 'AGG.US', 'GC.COMM', 'VOO.US', 'MCFTR.INDX', 'RGBITR.INDX', 'MOW_PR.RE', 'MOW_SEC.RE', 'RUCBTRNS.INDX', 'USDRUB.FX']

# %%
make_asset_list.ListMaker._get_asset_obj_dict(ls)
# Out:
# {'SPY.US': symbol                           SPY.US
#  name             SPDR S&P 500 ETF Trust
#  country                             USA
#  exchange                      NYSE ARCA
#  currency                            USD
#  type                                ETF
#  isin                       US78462F1030
#  first date                      1993-02
#  last date                       2025-02
#  period length                     32.00
#  dtype: object,
#  'AGG.US': symbol                                         AGG.US
#  name             iShares Core U.S. Aggregate Bond ETF
#  country                                           USA
#  exchange                                    NYSE ARCA
#  currency                                          USD
#  type                                              ETF
#  isin                                     US4642872265
#  first date                                    2003-10
#  last date                                     2025-02
#  period length                                   21.40
#  dtype: object,
#  'GC.COMM': symbol                GC.COMM
#  name             Gold (COMEX)
#  country                   USA
#  exchange                 COMM
#  currency                  USD
#  type                Commodity
#  isin
#  first date            1975-02
#  last date             2025-02
#  period length           50.00
#  dtype: object,
#  'VOO.US': symbol                         VOO.US
#  name             Vanguard S&P 500 ETF
#  country                           USA
#  exchange                    NYSE ARCA
#  currency                          USD
#  type                              ETF
#  isin                     US9229083632
#  first date                    2010-10
#  last date                     2025-02
#  period length                   14.30
#  dtype: object,
#  'MCFTR.INDX': symbol                               MCFTR.INDX
#  name             MOEX Russia Total Return Index
#  country                                  Russia
#  exchange                                   INDX
#  currency                                    RUB
#  type                                      INDEX
#  isin
#  first date                              1997-10
#  last date                               2025-02
#  period length                             27.40
#  dtype: object,
#  'RGBITR.INDX': symbol                          RGBITR.INDX
#  name             MOEX Government Bond Index
#  country                              Russia
#  exchange                               INDX
#  currency                                RUB
#  type                                  INDEX
#  isin
#  first date                          2003-01
#  last date                           2025-02
#  period length                         22.10
#  dtype: object,
#  'MOW_PR.RE': symbol                                     MOW_PR.RE
#  name             Moscow real estate. Primary market.
#  country                                       Russia
#  exchange                                          RE
#  currency                                         RUB
#  type                                     Real Estate
#  isin
#  first date                                   2000-04
#  last date                                    2024-12
#  period length                                  24.70
#  dtype: object,
#  'MOW_SEC.RE': symbol                                      MOW_SEC.RE
#  name             Moscow real estate. Secondary market.
#  country                                         Russia
#  exchange                                            RE
#  currency                                           RUB
#  type                                       Real Estate
#  isin
#  first date                                     2000-04
#  last date                                      2024-12
#  period length                                    24.70
#  dtype: object,
#  'RUCBTRNS.INDX': symbol                                           RUCBTRNS.INDX
#  name             Moscow Exchange Corporate Bond Index RUCBTRNS
#  country                                                 Russia
#  exchange                                                  INDX
#  currency                                                   RUB
#  type                                                     INDEX
#  isin
#  first date                                             2003-01
#  last date                                              2025-02
#  period length                                            22.10
#  dtype: object,
#  'USDRUB.FX': symbol                                                   USDRUB.FX
#  name             Central Bank of Russia exchange rate of US Dollar
#  country                                                     Russia
#  exchange                                                       CBR
#  currency                                                       RUB
#  type                                                      Currency
#  isin
#  first date                                                 1992-08
#  last date                                                  2025-03
#  period length                                                32.60
#  dtype: object}

# %%
al = ok.AssetList(ls, ccy='RUB', inflation=True)
print(al)
# Out:
# assets           [SPY.US, AGG.US, GC.COMM, VOO.US, MCFTR.INDX, ...
# currency                                                       RUB
# first_date                                                 2010-10
# last_date                                                  2024-12
# period_length                                   14 years, 3 months
# inflation                                                 RUB.INFL
# dtype: object

# %% [markdown]
# ## DCF

# %%
assets = ['MCFTR.INDX', 'GC.COMM', 'RGBITR.INDX', 'RUCBTRNS.INDX']
assets1 = ['MCFTR.INDX', 'GC.COMM']
assets2 = ['SPY.US', 'AGG.US', 'GC.COMM']

# %%
assets2
# Out:
# ['SPY.US', 'AGG.US', 'GC.COMM']

# %%
weights = [0.30, 0.55, 0.15]

pf = ok.Portfolio(
    assets2,
    ccy="USD",
    weights=weights,
    inflation=True,
    symbol="retirement_pf.PF",
    rebalancing_period="year",
)
pf
# Out:
# symbol                         retirement_pf.PF
# assets                [SPY.US, AGG.US, GC.COMM]
# weights                       [0.3, 0.55, 0.15]
# rebalancing_period                         year
# currency                                    USD
# inflation                              USD.INFL
# first_date                              2003-10
# last_date                               2025-01
# period_length                21 years, 4 months
# dtype: object

# %% [markdown]
# ### Indexation Strategy

# %%
ind = ok.IndexationStrategy(pf)
ind.initial_investment = 50_000
ind.amount = 100
ind.frequency = "month"

# %%
ind.amount
# Out:
# 100

# %%
ind.indexation
# Out:
# 0.02562697114698298

# %%
ind.periods_per_year
# Out:
# 12

# %%
pf.dcf.cashflow_parameters = ind

# %%
pf.dcf.use_discounted_values = False

# %%
print(pf.dcf.cashflow_parameters)
# Out:
# Portfolio symbol                retirement_pf.PF
# Cash flow initial investment               50000
# Cash flow frequency                        month
# Cash flow strategy                  fixed_amount
# Cash flow amount                             100
# Cash flow indexation                     0.02542
# dtype: object

# %%
pf.dcf.set_mc_parameters(
    distribution="norm",  # Normal distribution (or Gaussian distribution)
    period=10,
    number=100
)

# %%
pf.dcf.discount_rate = 0.05

# %%
pf.dcf.monte_carlo_wealth_fv.iloc[-1, :]
# Out:
# 0    170,719.61028
# 1    141,593.77819
# 2    134,723.39262
# 3    122,297.37464
# 4    116,157.07966
#           ...
# 95   110,142.31970
# 96   141,853.22607
# 97   110,374.94868
# 98   110,494.64492
# 99   137,187.52097
# Name: 2034-11, Length: 100, dtype: float64

# %%
pf.dcf.monte_carlo_wealth_pv.iloc[-1, :]
# Out:
# 0    104,086.18908
# 1     86,328.43494
# 2     82,139.62353
# 3     74,563.59372
# 4     70,819.91188
#           ...
# 95    67,152.76760
# 96    86,486.61795
# 97    67,294.59936
# 98    67,367.57707
# 99    83,641.98010
# Name: 2034-11, Length: 100, dtype: float64

# %%
pf.dcf.survival_date_hist(threshold=0)
# Out:
# Timestamp('2017-01-31 00:00:00')

# %%
pf.dcf.survival_period_hist()
# Out:
# 13.3

# %%
pf.dcf.wealth_index.plot()
# Out:
# <Axes: >

# %%
# Fixed Percentage strategy
pc = ok.PercentageStrategy(pf)
pc.initial_investment = 10_000
pc.frequency = "year"
pc.percentage = -0.12
pc
# Out:
# Portfolio symbol                portfolio_5530.PF
# Cash flow initial investment                10000
# Cash flow frequency                          year
# Cash flow strategy               fixed_percentage
# Cash flow percentage                     -0.12000
# dtype: object

# %%
# Fixed Amount strategy
ind = ok.IndexationStrategy(portf)
ind.initial_investment = 10_000
# ind.frequency = "year"
# ind.amount = -1500
# ind.indexation = "inflation"
ind
# Out:
# Portfolio symbol                portfolio_7702.PF
# Cash flow initial investment                10000
# Cash flow frequency                          None
# Cash flow strategy                   fixed_amount
# Cash flow amount                                0
# Cash flow indexation                      0.03081
# dtype: object

# %%
# TimeSeries strategy
d = {
    "2025-02": 1_000,
    "2029-03": -2_000,
}

d1 = {
    "2018-02": 2_000,
    "2024-03": -4_000,
}

ts = ok.TimeSeriesStrategy(portf)
ts.initial_investment = 1_000
ts.time_series_dic = d1

ts
# Out:
# Portfolio symbol                portfolio_7702.PF
# Cash flow initial investment                 1000
# Cash flow strategy                    time_series
# dtype: object

# %%
# Assign a strategy
pf.dcf.cashflow_parameters = pc
# pf.dcf.discount_rate = 0.10
# pf.dcf.use_discounted_values = False

# %%
pf.dcf
# Out:
# Portfolio symbol            portfolio_2953.PF
# Monte carlo distribution                 norm
# Monte carlo period                         25
# Cash flow strategy           fixed_percentage
# use_discounted_values                   False
# dtype: object

# %%
# Set Monte Carlo
pf.dcf.set_mc_parameters(distribution="t", period=10, number=100)

# %%
pf.dcf.mc.period = 10

# %%
pf.dcf.mc.period
# Out:
# 14

# %%
pf.dcf.cash_flow_parameters
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 portf.dcf.cash_flow_parameters
#
# AttributeError: 'PortfolioDCF' object has no attribute 'cash_flow_parameters'

# %%
pf.dcf.initial_investment_fv

# %%
pf.dcf.wealth_index.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df = pf.dcf.monte_carlo_wealth_pv

# %%
df.plot()
plt.legend("")

# %%
pf.dcf.plot_forecast_monte_carlo(backtest=True)

# %% [markdown]
# ### find_the_largest_withdrawals_size

# %%
assets = ['RGBITR.INDX', 'RUCBTRNS.INDX', 'MCFTR.INDX', 'GC.COMM']
weights = [0.16,          0.40,             0.25,        0.19]
pf = ok.Portfolio(assets, weights=weights, ccy='RUB', rebalancing_period='year', inflation=False)
pf.dcf.discount_rate = 0.09
print(pf)
# Out:
# symbol                                                portfolio_9596.PF
# assets                [RGBITR.INDX, RUCBTRNS.INDX, MCFTR.INDX, GC.COMM]
# weights                                         [0.16, 0.4, 0.25, 0.19]
# rebalancing_period                                                 year
# currency                                                            RUB
# inflation                                                          None
# first_date                                                      2003-01
# last_date                                                       2025-03
# period_length                                        22 years, 3 months
# dtype: object

# %%
ind = ok.IndexationStrategy(pf)
ind.initial_investment = 2_000_000 * 90
ind.amount = -4000 * 90
ind.frequency = "month"
ind.indexation = 0.09

pf.dcf.cashflow_parameters = ind
print(ind)
# Out:
# Portfolio symbol                portfolio_9596.PF
# Cash flow initial investment            180000000
# Cash flow frequency                         month
# Cash flow strategy                   fixed_amount
# Cash flow amount                          -360000
# Cash flow indexation                      0.09000
# dtype: object

# %%
ind.amount * 12 / ind.initial_investment * 100
# Out:
# -2.4

# %%
pf.dcf.mc.period = 50
pf.dcf.mc.number = 100
pf.dcf.mc.distribution = "norm"

# %%
pf.dcf.monte_carlo_survival_period().describe()
# Out:
# count   100.00000
# mean     49.03200
# std       3.33584
# min      32.20000
# 25%      50.00000
# 50%      50.00000
# 75%      50.00000
# max      50.00000
# dtype: float64

# %%
mc_wealth_pv = pf.dcf.monte_carlo_wealth_pv

# %%
mc50years_wealth_pv = mc_wealth_pv.iloc[-1, :]
mc50years_wealth_pv.describe([0.05, 0.20, 0.30, 0.50])
# Out:
# count              90.00000
# mean      400,707,166.39629
# std       331,212,582.94797
# min         8,107,953.18626
# 5%         39,702,834.57472
# 20%       143,359,085.40553
# 30%       200,303,716.07043
# 50%       308,283,047.77550
# max     1,797,835,507.07551
# Name: 2075-02, dtype: float64

# %%
pf.dcf.find_the_largest_withdrawals_size(
    goal="maintain_balance_pv",
    percentile=20,
    tolerance_rel=0.10,
)
# Out:
# [autoreload of pydevd failed: Traceback (most recent call last):
#   File "C:\Users\Komov\miniconda3\envs\py311\Lib\site-packages\IPython\extensions\autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#
#   File "C:\Users\Komov\miniconda3\envs\py311\Lib\site-packages\IPython\extensions\autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#
#   File "C:\Users\Komov\miniconda3\envs\py311\Lib\site-packages\IPython\extensions\autoreload.py", line 397, in update_generic
#     update(a, b)
#
#   File "C:\Users\Komov\miniconda3\envs\py311\Lib\site-packages\IPython\extensions\autoreload.py", line 365, in update_class
#     update_instances(old, new)
#
#   File "C:\Users\Komov\miniconda3\envs\py311\Lib\site-packages\IPython\extensions\autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
#
# TypeError: __class__ assignment: 'ThreadsSuspendedSingleNotification' object layout differs from 'ThreadsSuspendedSingleNotification'
# ]
# 207278783.98273996 -270000.0
# error_rel=0.152, gradient=0.000
# increasing withdrawal
# 0.0 -90405000.0
# error_rel=1.000, gradient=0.848
# decreasing withdrawal
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\py311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:641, in pandas._libs.index.PeriodEngine.get_loc()
#
# File index.pyx:652, in pandas._libs.index.PeriodEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1057
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pf.dcf.find_the_largest_withdrawals_size(
#       2     goal="maintain_balance_pv",
#       3     percentile=20,
#       4     tolerance_rel=0.10,
#       5 )
#
# File ~\PycharmProjects\okama\okama\portfolio.py:3082, in PortfolioDCF.find_the_largest_withdrawals_size(self, goal, target_survival_period, percentile, threshold, tolerance_rel, withdrawals_range, iter_max)
#    3080 solutions = pd.DataFrame(columns=["withdrawal", "error_rel", "error_rel_change"])
#    3081 while True:
# -> 3082     wealth_at_quantile = self.monte_carlo_wealth_pv.iloc[-1, :].quantile(percentile / 100)
#    3083     sp_at_quantile = self.monte_carlo_survival_period(threshold=0).quantile(percentile / 100)
#    3085     if goal in ["maintain_balance_fv", "maintain_balance_pv"]:
#
# File ~\PycharmProjects\okama\okama\portfolio.py:2842, in PortfolioDCF.monte_carlo_wealth_pv(self)
#    2810 @property
#    2811 def monte_carlo_wealth_pv(self) -> pd.DataFrame:
#    2812     """
#    2813     Portfolio discounted random wealth indexes with cash flows (withdrawals/contributions) by Monte Carlo simulation.
#    2814
#    (...)
#    2840     >>> plt.show()
#    2841     """
# -> 2842     wealth_df = self.monte_carlo_wealth_fv.copy()
#    2843     wealth_df_pv = pd.DataFrame()
#    2844     for n, row in enumerate(wealth_df.iterrows()):
#
# File ~\PycharmProjects\okama\okama\portfolio.py:2784, in PortfolioDCF.monte_carlo_wealth_fv(self)
#    2780 if self._monte_carlo_wealth.empty:
#    2781     return_ts = self.parent.monte_carlo_returns_ts(
#    2782         distr=self.mc.distribution, years=self.mc.period, n=self.mc.number
#    2783     )
# -> 2784     wealth_df = return_ts.apply(
#    2785         helpers.Frame.get_wealth_indexes_with_cashflow,
#    2786         axis=0,
#    2787         args=(
#    2788             None,  # portfolio_symbol
#    2789             None,  # inflation_symbol
#    2790             self.cashflow_parameters,
#    2791             False,  # use_discounted_values
#    2792         ),
#    2793     )
#    2795     def remove_negative_values(s):
#    2796         condition = s <= 0
#
# File ~\miniconda3\envs\py311\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~\miniconda3\envs\py311\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~\miniconda3\envs\py311\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~\miniconda3\envs\py311\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File ~\PycharmProjects\okama\okama\common\helpers\helpers.py:256, in Frame.get_wealth_indexes_with_cashflow(ror, portfolio_symbol, inflation_symbol, cashflow_parameters, use_discounted_values)
#     254         period_initial_amount = period_initial_amount * (r + 1) + cashflow
#     255         date = row[0]
# --> 256         s[date] = period_initial_amount
#     257 else:
#     258     pandas_frequency = settings.frequency_mapping[cashflow_parameters.frequency]
#
# File ~\miniconda3\envs\py311\Lib\site-packages\pandas\core\series.py:1298, in Series.__setitem__(self, key, value)
#    1295     return self._set_values(indexer, value, warn=warn)
#    1297 try:
# -> 1298     self._set_with_engine(key, value, warn=warn)
#    1299 except KeyError:
#    1300     # We have a scalar (or for MultiIndex or object-dtype, scalar-like)
#    1301     #  key that is not present in self.index.
#    1302     if is_integer(key):
#
# File ~\miniconda3\envs\py311\Lib\site-packages\pandas\core\series.py:1370, in Series._set_with_engine(self, key, value, warn)
#    1369 def _set_with_engine(self, key, value, warn: bool = True) -> None:
# -> 1370     loc = self.index.get_loc(key)
#    1372     # this is equivalent to self._values[key] = value
#    1373     self._mgr.setitem_inplace(loc, value, warn=warn)
#
# File ~\miniconda3\envs\py311\Lib\site-packages\pandas\core\indexes\period.py:510, in PeriodIndex.get_loc(self, key)
#     507     raise KeyError(key)
#     509 try:
# --> 510     return Index.get_loc(self, key)
#     511 except KeyError as err:
#     512     raise KeyError(orig_key) from err
#
# File ~\miniconda3\envs\py311\Lib\site-packages\pandas\core\indexes\base.py:3808, in Index.get_loc(self, key)
#    3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#    3807     if isinstance(casted_key, slice) or (
# -> 3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
#    3812     raise KeyError(key) from err
#
# File ~\miniconda3\envs\py311\Lib\abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Rolling and expanding risk

# %%
al = ok.AssetList(["SPY.US", "BND.US"])
al
# Out:
# assets             [SPY.US, BND.US]
# currency                        USD
# first_date                  2007-05
# last_date                   2024-01
# period_length    16 years, 9 months
# inflation                  USD.INFL
# dtype: object

# %%
al.risk_annual.plot()
# Out:
# <Axes: xlabel='date'>

# %%
al.get_rolling_risk_annual(window=12 * 5).plot()
# Out:
# <Axes: xlabel='date'>

# %%
al.describe()
# Out:
# C:\Users\Sergey\PycharmProjects\okama\okama\asset.py:175: FutureWarning: Resampling with a PeriodIndex is deprecated. Cast index to DatetimeIndex before resampling instead.
#   return div.resample("M").sum()
# C:\Users\Sergey\PycharmProjects\okama\okama\asset.py:175: FutureWarning: Resampling with a PeriodIndex is deprecated. Cast index to DatetimeIndex before resampling instead.
#   return div.resample("M").sum()
#                   property              period   SPY.US   BND.US inflation
# 0          Compound return                 YTD  0.01590 -0.00160   0.00540
# 1                     CAGR             1 years  0.20603  0.02105   0.03089
# 2                     CAGR             5 years  0.14194  0.00782   0.04148
# 3                     CAGR            10 years  0.12509  0.01565   0.02805
# 4                     CAGR  16 years, 9 months  0.09404  0.02918   0.02419
# 5   Annualized mean return  16 years, 9 months  0.10801  0.03024       NaN
# 6           Dividend yield                 LTM  0.01374  0.03090       NaN
# 7                     Risk  16 years, 9 months  0.17617  0.04695       NaN
# 8                     CVAR  16 years, 9 months  0.40832  0.15194       NaN
# 9            Max drawdowns  16 years, 9 months -0.50780 -0.17534       NaN
# 10     Max drawdowns dates  16 years, 9 months  2009-02  2022-10       NaN
# 11          Inception date                None  1993-02  2007-05   2007-05
# 12         Last asset date                None  2024-02  2024-02   2024-01
# 13   Common last data date                None  2024-01  2024-01   2024-01

# %% [markdown]
# ## Dividends

# %%
al = ok.AssetList(["SBERP.MOEX", "LKOH.MOEX"], ccy="RUB")
al
# Out:
# assets           [SBERP.MOEX, LKOH.MOEX]
# currency                             RUB
# first_date                       2006-09
# last_date                        2023-12
# period_length         17 years, 4 months
# inflation                       RUB.INFL
# dtype: object

# %%
al.dividends_annual
# Out:
#       SBERP.MOEX   LKOH.MOEX
# 2006     0.00000     0.00000
# 2007     0.46500    38.00000
# 2008     0.65000    42.00000
# 2009     0.63000    50.00000
# 2010     0.45000    52.00000
# 2011     1.15000    59.00000
# 2012     2.59000   115.00000
# 2013     3.20000   100.00000
# 2014     3.20000   120.00000
# 2015     0.45000   159.00000
# 2016     1.97000   187.00000
# 2017     6.00000   205.00000
# 2018    12.00000   225.00000
# 2019    16.00000   347.00000
# 2020    18.70000   396.00000
# 2021    18.70000   553.00000
# 2022     0.00000   793.00000
# 2023    25.00000 1,290.56000

# %%
al.dividend_yield
# Out:
#          SBERP.MOEX  LKOH.MOEX
# 2006-09     0.00000    0.00000
# 2006-10     0.00000    0.00000
# 2006-11     0.00000    0.00000
# 2006-12     0.00000    0.00000
# 2007-01     0.00000    0.00000
# ...             ...        ...
# 2023-08     0.09425    0.22437
# 2023-09     0.09580    0.22950
# 2023-10     0.09320    0.21406
# 2023-11     0.09058    0.21095
# 2023-12     0.09173    0.19069
#
# [208 rows x 2 columns]

# %%
al.dividend_yield_annual
# Out:
#       SBERP.MOEX  LKOH.MOEX
# 2006     0.00000    0.00000
# 2007     0.00667    0.01834
# 2008     0.07174    0.04368
# 2009     0.00913    0.02952
# 2010     0.00599    0.02985
# 2011     0.01943    0.03469
# 2012     0.03848    0.05749
# 2013     0.03999    0.04902
# 2014     0.08488    0.05393
# 2015     0.00588    0.06778
# 2016     0.01518    0.05422
# 2017     0.03175    0.06148
# 2018     0.07221    0.04503
# 2019     0.07008    0.05625
# 2020     0.07768    0.07663
# 2021     0.06723    0.08417
# 2022     0.00000    0.19472
# 2023     0.09173    0.19069

# %%
al.dividend_yield.resample(rule="Y").last()
# Out:
#       SBERP.MOEX  LKOH.MOEX
# 2006     0.00000    0.00000
# 2007     0.00667    0.01834
# 2008     0.07174    0.04368
# 2009     0.00913    0.02952
# 2010     0.00599    0.02985
# 2011     0.01943    0.03469
# 2012     0.03848    0.05749
# 2013     0.03999    0.04902
# 2014     0.08488    0.05393
# 2015     0.00588    0.06778
# 2016     0.01518    0.05422
# 2017     0.03175    0.06148
# 2018     0.07221    0.04503
# 2019     0.07008    0.05625
# 2020     0.07768    0.07663
# 2021     0.06723    0.08417
# 2022     0.00000    0.19472
# 2023     0.09173    0.19069

# %%
al.dividend_yield_annual.plot(kind="bar")
# Out:
# <Axes: >

# %%
al.get_dividend_mean_growth_rate()
# Out:
# SBERP.MOEX   -1.00000
# LKOH.MOEX     0.28652
# dtype: float64

# %%
al.get_dividend_mean_yield(10)
# Out:
# SBERP.MOEX   0.05166
# LKOH.MOEX    0.08849
# dtype: float64

# %% [markdown]
# ## Plot Wealth

# %%
def plot_wealth(
    al: object,
    first_date: str,
    last_date: str,
    legend: list,
    title: str = None,
    logy: bool = False,
    figsize: list = [12, 10],
):
    fig, ax = plt.subplots(figsize=figsize)
    # fig.subplots_adjust(bottom=0.2, top=1.5)
    first_date_dt = pd.to_datetime(first_date)
    last_date_dt = pd.to_datetime(last_date)

    wealth = al.wealth_indexes
    wealth = wealth.loc[first_date:last_date, :]
    index = wealth.index.to_timestamp()
    min_value = wealth.to_numpy().min()
    for i, asset in enumerate(wealth):
        if i == len(wealth.columns) - 1:
            # Inflation is in the last column
            continue
        ax.plot(index, wealth[asset], linewidth=2)
    ax.fill_between(index, min_value, wealth.iloc[:, -1], facecolor="grey", alpha=0.2, label="Инфляция")

    # Log scale
    y_scale = "log" if logy else "linear"
    ax.set_yscale(y_scale)

    # границы графика
    ax.set_xlim(first_date_dt, last_date_dt + pd.DateOffset(months=0))
    ax.set_ylim(bottom=min_value)

    # регулирования надписей оси Х
    years = mdates.YearLocator()  # ежегодный формат
    years_fmt = mdates.DateFormatter("%Y")
    # назначение формата надписей
    ax.xaxis.set_major_locator(years)
    ax.xaxis.set_major_formatter(years_fmt)

    ax.legend(legend + ["Инфляция"], loc="upper left")
    ax.set_title(title)

    # ax.set_ylabel('Инфляция за 12 месяцев, %')

# %%
stocks = ok.AssetList(["MCFTR.INDX", "SP500TR.INDX"], ccy="RUB", inflation=False)
stocks
# Out:
# assets           [MCFTR.INDX, SP500TR.INDX]
# currency                                RUB
# first_date                          1997-10
# last_date                           2024-02
# period_length            26 years, 5 months
# inflation                              None
# dtype: object

# %%
plot_wealth(
    al=stocks, first_date="2003-01", figsize=(14 / 1.1, 10 / 1.1), last_date="2023-01", legend=["Индекс ОФЗ"], logy=True
)

# %% [markdown]
# ## Efficiency frontier

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [12.0, 6.0]

import okama as ok

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# ### Convex function

# %%
ls = ["SPY.US", "GLD.US"]
curr = "USD"
y = ok.EfficientFrontierReb(
    assets=ls,
    first_date="2004-12",
    last_date="2020-10",
    ccy=curr,
    rebalancing_period="year",  # set rebalancing period to one year
    ticker_names=True,  # use tickers in DataFrame column names (can be set to False to show full assets names instead tickers)
    n_points=10,  # number of points in the Efficient Frontier
    verbose=True,
)  # verbose mode is ON to show progress while the EF points are calcualted

df_reb_year = y.ef_points

y.rebalancing_period = "none"

df_not_reb = y.ef_points

fig, ax = plt.subplots(figsize=(12, 10))

# Plot the Efficient Fronrier
ax.plot(df_reb_year.Risk, df_reb_year.CAGR, label="Annually rebalanced")
ax.plot(df_not_reb.Risk, df_not_reb.CAGR, label="Not rebalanced")

# Plot the aseets
y.plot_assets(kind="cagr")

# Set axis labels
ax.set_xlabel("Risk (Standard Deviation)")
ax.set_ylabel("CAGR")
ax.legend();
# Out:
# 2025-03-24 20:50:06,780 - INFO - left EF point #1/10 is done in 0.47 sec.
# 2025-03-24 20:50:07,209 - INFO - left EF point #2/10 is done in 0.95 sec.
# 2025-03-24 20:50:08,209 - INFO - left EF point #3/10 is done in 1.32 sec.
# 2025-03-24 20:50:08,385 - INFO - left EF point #4/10 is done in 1.02 sec.
# 2025-03-24 20:50:09,269 - INFO - left EF point #5/10 is done in 1.05 sec.
# 2025-03-24 20:50:09,464 - INFO - left EF point #6/10 is done in 1.07 sec.
# 2025-03-24 20:50:10,634 - INFO - left EF point #7/10 is done in 1.36 sec.
# 2025-03-24 20:50:10,807 - INFO - left EF point #8/10 is done in 1.33 sec.
# 2025-03-24 20:50:11,782 - INFO - left EF point #9/10 is done in 1.14 sec.
# 2025-03-24 20:50:13,133 - INFO - left EF point #10/10 is done in 2.32 sec.
# 2025-03-24 20:50:17,439 - INFO - right EF point #1/8 is done in 2.57 sec.
# 2025-03-24 20:50:17,623 - INFO - right EF point #2/8 is done in 2.75 sec.
# 2025-03-24 20:50:19,606 - INFO - right EF point #4/8 is done in 1.96 sec.
# 2025-03-24 20:50:19,783 - INFO - right EF point #3/8 is done in 2.32 sec.
# 2025-03-24 20:50:21,732 - INFO - right EF point #5/8 is done in 2.12 sec.
# 2025-03-24 20:50:21,772 - INFO - right EF point #6/8 is done in 1.98 sec.
# 2025-03-24 20:50:23,066 - INFO - right EF point #8/8 is done in 1.29 sec.
# 2025-03-24 20:50:23,480 - INFO - right EF point #7/8 is done in 1.74 sec.
# 2025-03-24 20:50:23,493 - INFO - Total time taken is 0.34 min.
# 2025-03-24 20:50:23,601 - INFO - left EF point #1/10 is done in 0.06 sec.
# 2025-03-24 20:50:23,695 - INFO - left EF point #3/10 is done in 0.09 sec.
# 2025-03-24 20:50:23,698 - INFO - left EF point #2/10 is done in 0.16 sec.
# 2025-03-24 20:50:23,769 - INFO - left EF point #4/10 is done in 0.07 sec.
# 2025-03-24 20:50:23,787 - INFO - left EF point #5/10 is done in 0.08 sec.
# 2025-03-24 20:50:23,855 - INFO - left EF point #7/10 is done in 0.08 sec.
# 2025-03-24 20:50:23,858 - INFO - left EF point #6/10 is done in 0.07 sec.
# 2025-03-24 20:50:23,928 - INFO - left EF point #8/10 is done in 0.07 sec.
# 2025-03-24 20:50:23,938 - INFO - left EF point #9/10 is done in 0.08 sec.
# 2025-03-24 20:50:23,994 - INFO - left EF point #10/10 is done in 0.06 sec.
# 2025-03-24 20:50:24,050 - INFO - Total time taken is 0.01 min.

# %% [markdown]
# ### Non-convex function

# %%
ls_m = ["SPY.US", "GLD.US", "VB.US", "RGBITR.INDX", "MCFTR.INDX"]
curr_rub = "RUB"

x = ok.EfficientFrontierReb(
    assets=ls_m,
    first_date="2004-12",
    last_date="2020-12",
    ccy=curr_rub,
    rebalancing_period="year",  # set rebalancing period to one year
    n_points=10,
    verbose=True,
)

df1_reb_year = x.ef_points

x.rebalancing_period = "none"

df1_not_reb = x.ef_points

fig, ax = plt.subplots(figsize=(12, 10))

# Plot the Efficient Frontiers
ax.plot(df1_reb_year.Risk, df1_reb_year.CAGR, label="Annually rebalanced")
ax.plot(df1_not_reb.Risk, df1_not_reb.CAGR, label="Not rebalanced")

# Plot the assets
x.plot_assets(kind="cagr")

# Set labels
ax.set_xlabel("Risk (Standard Deviation)")
ax.set_ylabel("CAGR")
ax.legend();
# Out:
# 2025-03-23 22:54:19,434 - INFO - left EF point #1/10 is done in 0.57 sec.
# 2025-03-23 22:54:21,541 - INFO - left EF point #3/10 is done in 2.10 sec.
# 2025-03-23 22:54:21,652 - INFO - left EF point #2/10 is done in 2.79 sec.
# 2025-03-23 22:54:23,500 - INFO - left EF point #4/10 is done in 1.96 sec.
# 2025-03-23 22:54:24,004 - INFO - left EF point #5/10 is done in 2.35 sec.
# 2025-03-23 22:54:25,769 - INFO - left EF point #6/10 is done in 2.27 sec.
# 2025-03-23 22:54:26,642 - INFO - left EF point #7/10 is done in 2.63 sec.
# 2025-03-23 22:54:28,773 - INFO - left EF point #8/10 is done in 3.00 sec.
# 2025-03-23 22:54:29,945 - INFO - left EF point #9/10 is done in 3.30 sec.
# 2025-03-23 22:54:34,165 - INFO - left EF point #10/10 is done in 5.39 sec.
# 2025-03-23 22:54:45,240 - INFO - right EF point #2/3 is done in 5.34 sec.
# 2025-03-23 22:54:45,351 - INFO - right EF point #1/3 is done in 5.45 sec.
# 2025-03-23 22:54:48,801 - INFO - right EF point #3/3 is done in 3.56 sec.
# 2025-03-23 22:54:48,805 - INFO - Total time taken is 0.51 min.
# 2025-03-23 22:54:48,961 - INFO - left EF point #1/10 is done in 0.10 sec.
# 2025-03-23 22:54:49,046 - INFO - left EF point #2/10 is done in 0.18 sec.
# 2025-03-23 22:54:49,297 - INFO - left EF point #4/10 is done in 0.25 sec.
# 2025-03-23 22:54:49,335 - INFO - left EF point #3/10 is done in 0.37 sec.
# 2025-03-23 22:54:49,669 - INFO - left EF point #7/10 is done in 0.33 sec.
# 2025-03-23 22:54:49,752 - INFO - left EF point #5/10 is done in 0.45 sec.
# 2025-03-23 22:54:50,029 - INFO - left EF point #8/10 is done in 0.36 sec.
# 2025-03-23 22:54:50,029 - INFO - left EF point #6/10 is done in 0.28 sec.
# 2025-03-23 22:54:50,155 - INFO - left EF point #10/10 is done in 0.12 sec.
# 2025-03-23 22:54:50,333 - INFO - left EF point #9/10 is done in 0.30 sec.
# 2025-03-23 22:54:50,511 - INFO - Total time taken is 0.03 min.

# %% [markdown]
# ## Different bounds

# %%
ls_m = ["VOO.US", "GLD.US", "SCHA.US"]
curr_rub = "USD"

x = ok.EfficientFrontierReb(
    assets=ls_m,
    first_date="2004-10",
    last_date="2020-10",
    ccy=curr_rub,
    n_points=15,
    bounds=((0, 1), (0, 1), (0, 1)),  # add bounds
    verbose=False,
)

x.rebalancing_period = "none"
df1_not_reb = x.ef_points

x.rebalancing_period = "year"
df1_reb_year = x.ef_points


y = ok.EfficientFrontierReb(
    assets=ls_m,
    first_date="2004-10",
    last_date="2020-10",
    ccy=curr_rub,
    n_points=15,
    bounds=((0, 0.4), (0, 1), (0, 1)),  # add bounds
    verbose=False,
)

y.rebalancing_period = "none"
df2_not_reb = y.ef_points

y.rebalancing_period = "year"
df2_reb_year = y.ef_points

fig, ax = plt.subplots(figsize=(16, 14))

# Plot not rebalanced frontier for x
ax.plot(df1_not_reb.Risk, df1_not_reb.CAGR, label="Not rebalanced (First set of bounds)", color="yellow")

# Plot yearly rebalanced frontier for x
ax.plot(df1_reb_year.Risk, df1_reb_year.CAGR, label="Annually rebalanced (First set of bounds)", color="red")

# Plot not rebalanced frontier for y
ax.plot(df2_not_reb.Risk, df2_not_reb.CAGR, label="Not rebalanced (Second set of bounds)", color="green")

# Plot yearly rebalanced frontier for y
ax.plot(df2_reb_year.Risk, df2_reb_year.CAGR, label="Annually rebalanced (Second set of bounds)", color="blue")

# Plot the assets
x.plot_assets(kind="cagr")

# Set axis labels
ax.set_xlabel("Risk (Standard Deviation)")
ax.set_ylabel("CAGR")
ax.legend()
plt.show()

# %% [markdown]
# ## Plot Pair Efficient Frontier for different periods

# %%
pf = ["SPY.US", "GLD.US", "VB.US"]

curr = 'RUB'

last_date="2024-07"

bounds=((0, 1), (0, 1), (0, 1))

ef = ok.EfficientFrontierReb(pf, ccy=curr, last_date=last_date, bounds=bounds)

ef.plot_pair_ef()

plt.show()

# %% [markdown]
# ## Monte Carlo simulation

# %% [markdown]
# ### Default bounds

# %%
assets = ["VOO.US", "GLD.US", "SCHA.US"]
curr = "USD"

x_1 = ok.EfficientFrontierReb(
    assets=assets,
    first_date="2004-10",
    last_date="2020-10",
    ccy=curr,
    verbose=False,
)

df_1 = x_1.ef_points

monte_carlo_1 = x_1.get_monte_carlo(n=1000)

fig, ax = plt.subplots(figsize=(12, 10))

# Plot Monte Carlo simulation and the Eficient Frontier
ax.plot(df_1.Risk, df_1.CAGR, color="black")
ax.scatter(monte_carlo_1.Risk, monte_carlo_1.CAGR, color="green")  # draw the random portfolios risk-return points

# Plot the assets
x_1.plot_assets(kind="cagr")

ax.set_xlabel("Risk (Standard Deviation)")
ax.set_ylabel("CAGR");

# %% [markdown]
# ### Custom bounds

# %%
assets = ["VOO.US", "GLD.US", "SCHA.US"]
curr = "USD"

x_2 = ok.EfficientFrontierReb(
    assets=assets,
    first_date="2004-10",
    last_date="2020-10",
    ccy=curr,
    bounds=((0, 0.4), (0, 1), (0, 1)),  # add bounds    
    verbose=False,
)

df_2 = x_2.ef_points

monte_carlo_2 = x_2.get_monte_carlo(n=1000)

fig, ax = plt.subplots(figsize=(12, 10))

# Plot Monte Carlo simulation and the Eficient Frontier
ax.plot(df_2.Risk, df_2.CAGR, color="black")
ax.scatter(monte_carlo_2.Risk, monte_carlo_2.CAGR, color="orange")  # draw the random portfolios risk-return points

# Plot the assets
x_2.plot_assets(kind="cagr")

ax.set_xlabel("Risk (Standard Deviation)")
ax.set_ylabel("CAGR");

# %% [markdown]
# ## Problem with optimization for 2 assets

# %%
ef = ok.EfficientFrontierReb(['SPY.US', 'MCFTR.INDX'], ccy='RUB', last_date='2025-03', bounds=None)

# %%
ef = ok.EfficientFrontierReb(['SPY.US', 'GLD.US'], ccy='USD', last_date='2020-10', bounds=None)

# %%
df1_reb_year = ef.ef_points

fig, ax = plt.subplots(figsize=(12, 10))

# Plot the Efficient Frontiers
ax.plot(df1_reb_year.Risk, df1_reb_year.CAGR, label="Annually rebalanced")
# ax.plot(df1_not_reb.Risk, df1_not_reb.CAGR, label="Not rebalanced")

# Plot the assets
ef.plot_assets(kind="cagr")
# Out:
# <Axes: >

# %%
df1_reb_year
# Out:
#       Risk    CAGR  SPY.US  MCFTR.INDX
# 0  0.44854 0.16973 0.00000     1.00000
# 1  0.44468 0.17261 0.00899     0.99101
# 2  0.44107 0.17550 0.01858     0.98142
# 3  0.43768 0.17838 0.02881     0.97119
# 4  0.43448 0.18126 0.03974     0.96026
# 5  0.43143 0.18414 0.05143     0.94857
# 6  0.42848 0.18703 0.06397     0.93603
# 7  0.42560 0.18991 0.07742     0.92258
# 8  0.42276 0.19279 0.09192     0.90808
# 9  0.41990 0.19568 0.10758     0.89242
# 10 0.41701 0.19856 0.12456     0.87544
# 11 0.41402 0.20144 0.14309     0.85691
# 12 0.41089 0.20432 0.16343     0.83657
# 13 0.40757 0.20721 0.18595     0.81405
# 14 0.40398 0.21009 0.21121     0.78879
# 15 0.40004 0.21297 0.24001     0.75999
# 16 0.39560 0.21585 0.27375     0.72625
# 17 0.39040 0.21874 0.31510     0.68490
# 18 0.38383 0.22162 0.37096     0.62904
# 19 0.36990 0.22450 0.51344     0.48656
# 20 0.38383 0.22162 0.37096     0.62904
# 21 0.39040 0.21874 0.31510     0.68490
# 22 0.39560 0.21585 0.27375     0.72625
# 23 0.40004 0.21297 0.24001     0.75999
# 24 0.40398 0.21009 0.21121     0.78879
# 25 0.40757 0.20721 0.18595     0.81405
# 26 0.41089 0.20432 0.16343     0.83657
# 27 0.41402 0.20144 0.14309     0.85691
# 28 0.41701 0.19856 0.12456     0.87544
# 29 0.41990 0.19568 0.10758     0.89242
# 30 0.42276 0.19279 0.09192     0.90808
# 31 0.42560 0.18991 0.07742     0.92258
# 32 0.42848 0.18703 0.06397     0.93603
# 33 0.43143 0.18414 0.05143     0.94857
# 34 0.43448 0.18126 0.03974     0.96026
# 35 0.43768 0.17838 0.02881     0.97119
# 36 0.44107 0.17550 0.01858     0.98142
# 37 0.44468 0.17261 0.00899     0.99101
# 38 0.44854 0.16973 0.00000     1.00000
