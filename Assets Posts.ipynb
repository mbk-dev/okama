# %%
from okama.frontier import Plots
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Assets Plots

# %%
x = Plots(['SPY.US', 'GLD.US', 'GAZP.MCX'], curr='RUB')

# %%
type(x.ax)
# Out:
# NoneType

# %%
x.plot_assets()
x.plot_assets(type='cagr_app')
x.plot_assets(type='cagr')

# %%
Plots(['SPY.US', 'GLD.US']).plot_assets()

# %%
Plots().plot_assets()
