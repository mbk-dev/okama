# %%
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt

from okama.assets import Asset, AssetList, Portfolio
from okama.frontier import EfficientFrontier, EfficientFrontierReb, Plots
from okama.helpers import Rebalance, Frame, Float

pd.options.display.float_format = '{:,.4f}'.format

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Efficient Frontier

# %%
list1 = ['BND.US', 'SPY.US']
list2 = list1 + ['GLD.US']
ef1 = EfficientFrontier(symbols=list1, curr='RUB').ef_points
ef2 = EfficientFrontier(symbols=list2, curr='RUB').ef_points

# Рисуем границы
fig = plt.figure(figsize=(12,6))
fig.subplots_adjust(bottom=0.2, top=1.5)
Plots(['SPY.US', 'BND.US', 'GLD.US'], curr='RUB').plot_assets()
ax = plt.gca()
ax.plot(ef1.Risk, ef1.Return)
ax.plot(ef2.Risk, ef2.Return)

# %%
list1 = ['BND.US', 'SPY.US', 'GLD.US']
list2 = list1 + ['0890-94127385.RUFUND'] # Индекс Мосбиржи
e1 = EfficientFrontier(symbols=list1, first_date='2007-08', curr='RUB')
e2 = EfficientFrontier(symbols=list2, first_date='2007-08', curr='RUB')
ef1 = e1.ef_points
ef2 = e2.ef_points

# %%
e1.first_date
# Out:
# Timestamp('2007-08-01 00:00:00')

# %%
e2.first_date
# Out:
# Timestamp('2007-08-01 00:00:00')

# %%
# Рисуем границы
fig = plt.figure(figsize=(12,6))
fig.subplots_adjust(bottom=0.2, top=1.5)
Plots(['SPY.US', 'BND.US', 'GLD.US', '0890-94127385.RUFUND'], curr='RUB').plot_assets()
ax = plt.gca()
ax.plot(ef1.Risk, ef1.Return)
ax.plot(ef2.Risk, ef2.Return)

# %%
ef = EfficientFrontier(symbols=['SPY.US', 'GLD.US', 'VNQ.US', 'BND.US']).ef_points
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\envs\py38\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     155         try:
# --> 156             conn = connection.create_connection(
#     157                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\Anaconda3\envs\py38\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\envs\py38\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\envs\py38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664             # Make the request on the httplib connection object.
# --> 665             httplib_response = self._make_request(
#     666                 conn,
#
# ~\Anaconda3\envs\py38\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\envs\py38\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# ~\Anaconda3\envs\py38\lib\site-packages\urllib3\connection.py in connect(self)
#     333         # Add certificate verification
# --> 334         conn = self._new_conn()
#     335         hostname = self.host
#
# ~\Anaconda3\envs\py38\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167         except SocketError as e:
# --> 168             raise NewConnectionError(
#     169                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x00000170E7366760>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\envs\py38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\Anaconda3\envs\py38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     718
# --> 719             retries = retries.increment(
#     720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\Anaconda3\envs\py38\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='eodhistoricaldata.com', port=443): Max retries exceeded with url: /api/eod/SPY.US?api_token=5cf7a8132af958.27978804 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000170E7366760>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-2a2fcf60cf88> in <module>
# ----> 1 ef = EfficientFrontier(symbols=['SPY.US', 'GLD.US', 'VNQ.US', 'BND.US']).ef_points
#
# ~\OneDrive\NoteBooks\okama\okama\frontier.py in __init__(self, symbols, first_date, last_date, curr, full_frontier, n)
#      23         if len(symbols) < 2:
#      24             raise ValueError('The number of symbols cannot be less than two')
# ---> 25         super().__init__(symbols, first_date, last_date, curr)
#      26         self.full_frontier = full_frontier
#      27         self.n_points = n
#
# ~\OneDrive\NoteBooks\okama\okama\assets.py in __init__(self, symbols, first_date, last_date, curr)
#      56         self.tickers = symbols
#      57         self.currency = curr
# ---> 58         self._make_asset_list(symbols)
#      59         if first_date:
#      60             self.ror = self.ror[pd.to_datetime(first_date):]
#
# ~\OneDrive\NoteBooks\okama\okama\assets.py in _make_asset_list(self, ls)
#      70         """
#      71         for i, x in enumerate(ls):
# ---> 72             asset = Asset(x)
#      73             if i == 0:
#      74                 if asset.asset_currency == self.currency:
#
# ~\OneDrive\NoteBooks\okama\okama\assets.py in __init__(self, symbol)
#      16     def __init__(self, symbol=default_ticker):
#      17         self.ticker = symbol
# ---> 18         self.ror = self._get_monthly_ror(symbol)
#      19         self.market = self._define_market(symbol)
#      20         self.asset_currency = self._define_currency()
#
# ~\OneDrive\NoteBooks\okama\okama\assets.py in _get_monthly_ror(self, ticker)
#      24         Calculate monthly mean return time series given the ticker.
#      25         """
# ---> 26         s = get_eod_data(ticker)
#      27         name = s.name
#      28         s = s.resample('M').apply(lambda x: (np.prod(1 + x) - 1))
#
# ~\OneDrive\NoteBooks\okama\okama\data.py in get_eod_data(symbol, type, session)
#      18     url = EOD_url + symbol
#      19     params = {'api_token': api_token}
# ---> 20     r = session.get(url, params=params, verify=False)
#      21     if r.status_code == requests.codes.ok:
#      22         r.connection.close()  # TODO: check if closing connection slows down multiple requests
#
# ~\Anaconda3\envs\py38\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# ~\Anaconda3\envs\py38\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\Anaconda3\envs\py38\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\py38\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='eodhistoricaldata.com', port=443): Max retries exceeded with url: /api/eod/SPY.US?api_token=5cf7a8132af958.27978804 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000170E7366760>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
ef.plot(x='Risk', y='Return')
