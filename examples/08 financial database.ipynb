# %% [markdown]
# <a href="https://colab.research.google.com/github/mbk-dev/okama/blob/master/examples/08%20financial%20database.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %% [markdown]
# You can run the code examples in [Google Colab](https://colab.research.google.com/github/mbk-dev/okama/blob/master/examples/08%20financial%20database.ipynb).

# %% [markdown]
# **To install the package:**

# %%
# !pip install okama

# %% [markdown]
# import okama and matplotlib packages ...

# %%
import okama as ok

# %% [markdown]
# Financial Database of *okama* has stock market securities, currencies, commodities and indexes as well as macroeconomic indicators  historical data.

# %% [markdown]
# ### Stock markets
#
# - Stocks and ETF for main world markets
# - Mutual funds
# - Commodities
# - Stock indexes
#
# ### Currencies
#
# - FX currencies
# - Crypto currencies
# - Central bank exchange rates
#
# ### Macroeconomic indicators
#
# - Inflation (USA, United Kingdom, European Union, Israel, Russia etc.)
# - Central bank rates
#
# ### Other historical data
#
# - Real estate prices
# - Top bank rates

# %% [markdown]
# ___

# %% [markdown]
# ## Search the Database

# %% [markdown]
# To search for a ticker or security name use `ok.search` method.

# %%
ok.search("tesla")  # it's not case-sensitive
# Out:
#           symbol     ticker  \
# 0       2STE.LSE       2STE
# 1       2TSE.LSE       2TSE
# 2       2TSL.LSE       2TSL
# 3       STSE.LSE       STSE
# 4       STSL.LSE       STSL
# 5       TS3S.LSE       TS3S
# 6       TSL3.LSE       TSL3
# 7       TSLA.LSE       TSLA
# 8       TSLD.LSE       TSLD
# 9       TSLI.LSE       TSLI
# 10      TSLQ.LSE       TSLQ
# 11      TSLS.LSE       TSLS
# 12    1STS.XETRA       1STS
# 13    3TSE.XETRA       3TSE
# 14    TS3S.XETRA       TS3S
# 15       TSLA.US       TSLA
# 16       TSLP.US       TSLP
# 17       TSLT.US       TSLT
# 18       TSLZ.US       TSLZ
# 19     1STS.XETR       1STS
# 20     3TSE.XETR       3TSE
# 21      TL0.XETR        TL0
# 22  mTSLA-USD.CC  mTSLA-USD
# 23    TES-USD.CC    TES-USD
# 24   TSLA-USD.CC   TSLA-USD
# 25      1TSL.LSE       1TSL
# 26      3LTE.LSE       3LTE
# 27      3LTP.LSE       3LTP
# 28      3LTS.LSE       3LTS
# 29      3STE.LSE       3STE
# 30      3STL.LSE       3STL
# 31      3STP.LSE       3STP
# 32      3STS.LSE       3STS
# 33      3TSE.LSE       3TSE
# 34      3TSL.LSE       3TSL
# 35         TL0.F        TL0
# 36        TL01.F       TL01
# 37       TL0.STU        TL0
# 38     TL0.XETRA        TL0
# 39      TXLZF.US      TXLZF
# 40     TS3S.XETR       TS3S
# 41      TL0.XFRA        TL0
# 42     TL01.XFRA       TL01
# 43      TL0.XSTU        TL0
#
#                                                  name  country exchange  \
# 0             Leverage Shares -2x Short Tesla ETP EUR       UK      LSE
# 1                    Leverage Shares 2x Tesla ETC EUR       UK      LSE
# 2                    Leverage Shares 2x Tesla ETP Scs       UK      LSE
# 3        Leverage Shares -1x Tesla ETP Securities EUR       UK      LSE
# 4                       Leverage Shares -1x Tesla ETC       UK      LSE
# 5      Leverage Shares -3x Short Tesla ETP Securities       UK      LSE
# 6             Leverage Shares 3x Tesla ETP Securities       UK      LSE
# 7              LS 1x Tesla Tracker ETP Securities GBP       UK      LSE
# 8                 IncomeShares Tesla TSLA Options ETP       UK      LSE
# 9                 IncomeShares Tesla TSLA Options ETP       UK      LSE
# 10  Leverage Shares -3x Short Tesla ETP Securities...       UK      LSE
# 11           Leverage Shares -1x Tesla ETP Securities       UK      LSE
# 12           Leverage Shares -1x Tesla ETP Securities  Germany    XETRA
# 13            Leverage Shares 3x Tesla ETP Securities  Germany    XETRA
# 14                Leverage Shares -3x Short Tesla ETC  Germany    XETRA
# 15                                          Tesla Inc      USA   NASDAQ
# 16         Kurv Yield Premium Strategy Tesla TSLA ETF      USA     BATS
# 17               T-REX 2X Long Tesla Daily Target ETF      USA   NASDAQ
# 18            T-Rex 2X Inverse Tesla Daily Target ETF      USA   NASDAQ
# 19           Leverage Shares -1x Tesla ETP Securities  Germany     XETR
# 20            Leverage Shares 3x Tesla ETP Securities  Germany     XETR
# 21                                          Tesla Inc  Germany     XETR
# 22                                     Mirrored Tesla  Unknown       CC
# 23                                          TeslaCoin  Unknown       CC
# 24                                              Tesla  Unknown       CC
# 25                            LS 1x Tesla Tracker ETC       UK      LSE
# 26          GraniteShares 3x Long Tesla Daily ETP EUR       UK      LSE
# 27          GraniteShares 3x Long Tesla Daily ETP GBP       UK      LSE
# 28              GraniteShares 3x Long Tesla Daily ETP       UK      LSE
# 29             GraniteShares 3x Short Tesla Daily ETP       UK      LSE
# 30  Leverage Shares -3x Short Tesla ETP Securities...       UK      LSE
# 31             GraniteShares 3x Short Tesla Daily ETP       UK      LSE
# 32             GraniteShares 3x Short Tesla Daily ETP       UK      LSE
# 33        Leverage Shares 3x Tesla ETP Securities EUR       UK      LSE
# 34        Leverage Shares 3x Tesla ETP Securities GBX       UK      LSE
# 35                                          Tesla Inc  Germany        F
# 36                              TESLA INC. CDR DL-001  Germany        F
# 37                                          Tesla Inc  Germany      STU
# 38                                          Tesla Inc  Germany    XETRA
# 39                              Tesla Exploration Ltd      USA     PINK
# 40                Leverage Shares -3x Short Tesla ETC  Germany     XETR
# 41                                          Tesla Inc  Germany     XFRA
# 42                              TESLA INC. CDR DL-001  Germany     XFRA
# 43                                          Tesla Inc  Germany     XSTU
#
#    currency          type          isin
# 0       EUR           ETF  XS2297550134
# 1       EUR           ETF  IE00BK5BZY66
# 2       GBX           ETF
# 3       EUR           ETF  IE00BKT6ZH01
# 4       GBX           ETF  IE00BKT6ZH01
# 5       USD           ETF  XS2337090265
# 6       USD           ETF  XS2757381400
# 7       GBX           ETF  XS2337093798
# 8       GBX           ETF  XS2852999429
# 9       USD           ETF  XS2852999429
# 10      GBP           ETF
# 11      USD           ETF  IE00BKT6ZH01
# 12      EUR           ETF  IE00BKT6ZH01
# 13      EUR           ETF  XS2757381400
# 14      EUR           ETF  XS2337090265
# 15      USD  Common Stock  US88160R1014
# 16      USD           ETF
# 17      USD           ETF  US26923N8359
# 18      USD           ETF  US26923N8276
# 19      EUR           ETF  IE00BKT6ZH01
# 20      EUR           ETF  XS2297549128
# 21      EUR  Common Stock  US88160R1014
# 22      USD      Currency
# 23      USD      Currency
# 24      USD      Currency
# 25      USD           ETF  XS2337093798
# 26      EUR           ETF  XS2193972598
# 27      GBX           ETF
# 28      USD           ETF  XS2193972598
# 29      EUR           ETF  XS2193972671
# 30      EUR           ETF  XS2337090265
# 31      GBX           ETF  XS2193972671
# 32      USD           ETF  XS2193972671
# 33      EUR           ETF  XS2757381400
# 34      GBX           ETF  XS2757381400
# 35      EUR  Common Stock  US88160R1014
# 36      EUR  Common Stock  CA88162R1091
# 37      EUR  Common Stock  US88160R1014
# 38      EUR  Common Stock  US88160R1014
# 39      USD  Common Stock
# 40      EUR           ETF  XS2337090265
# 41      EUR  Common Stock  US88160R1014
# 42      EUR  Common Stock  CA88162R1091
# 43      EUR  Common Stock  US88160R1014

# %% [markdown]
# It is possible to search for ISIN with the same method.

# %%
ok.search("US78462F103")
# Out:
#    symbol ticker                    name country   exchange currency type  \
# 0  SPY.US    SPY  SPDR S&P 500 ETF Trust     USA  NYSE ARCA      USD  ETF
#
#            isin
# 0  US78462F1030

# %% [markdown]
# ## Namespaces: Financial Database sections

# %% [markdown]
# Namespase is a set of characters after the period in the ticker (SPY**.US**).

# %% [markdown]
# Namespaces are based on MIC (Market Identifier Codes) and okama own code systems for macro parameters.

# %%
# available namespaces
ok.namespaces
# Out:
# {'CBR': 'Central Banks official currency exchange rates',
#  'CC': 'Cryptocurrency pairs with USD',
#  'COMM': 'Commodities prices',
#  'FX': 'FOREX currency market',
#  'INDX': 'Indexes',
#  'INFL': 'Inflation',
#  'LSE': 'London Stock Exchange',
#  'MOEX': 'Moscow Exchange',
#  'PF': 'Investment Portfolios',
#  'PIF': 'Russian open-end mutual funds',
#  'RATE': 'Bank deposit rates',
#  'RATIO': 'Financial ratios',
#  'RE': 'Real estate prices',
#  'US': 'US Stock Exchanges and mutual funds',
#  'XAMS': 'Euronext Amsterdam',
#  'XETR': 'XETRA Exchange',
#  'XFRA': 'Frankfurt Stock Exchange',
#  'XSTU': 'Stuttgart Exchange',
#  'XTAE': 'Tel Aviv Stock Exchange (TASE)'}

# %% [markdown]
# It is possible to request all symbols in a sertain namespace with `ok.symbols_in_namespace`:

# %%
# available symbols in namespace
ok.symbols_in_namespace("INDX")  # all stock indexes
# Out:
#             symbol   ticker                                name  country  \
# 0      000906.INDX   000906                China Securities 800    China
# 1        0O7N.INDX     0O7N              Scale All Share GR EUR  Germany
# 2        3LHE.INDX     3LHE           ESTX 50 Corporate Bond TR   Greece
# 3     5SP2550.INDX  5SP2550  S&P 500 Retailing (Industry Group)      USA
# 4        ADVA.INDX     ADVA               AMEX Advancing Stocks  Unknown
# ...            ...      ...                                 ...      ...
# 1776    XU100.INDX    XU100                            BIST 100   Turkey
# 1777    XUSIN.INDX    XUSIN                    BIST Industrials   Turkey
# 1778    XUSRD.INDX    XUSRD                 BIST Sustainability   Turkey
# 1779    XUTEK.INDX    XUTEK                     BIST Technology   Turkey
# 1780     YMU0.INDX     YMU0        E-mini Dow $5 Future Sept 20      USA
#
#      exchange currency     type isin
# 0        INDX      USD    INDEX
# 1        INDX      EUR    INDEX
# 2        INDX      EUR    INDEX
# 3        INDX      USD    INDEX
# 4        INDX      USD    INDEX
# ...       ...      ...      ...  ...
# 1776     INDX      TRY    INDEX
# 1777     INDX      TRY    INDEX
# 1778    INDEX      TRY    INDEX
# 1779    INDEX      TRY    INDEX
# 1780     INDX      USD  Futures
#
# [1781 rows x 8 columns]

# %% [markdown]
# ## Advanced search

# %% [markdown]
# To limit the search use `namespace` argument:

# %%
ok.search("AstraZeneca", namespace="LSE")
# Out:
#         symbol ticker                                          name country  \
# 27    0A4J.LSE   0A4J                           AstraZeneca PLC ADR      UK
# 2609  3SAZ.LSE   3SAZ  GraniteShares 3x Short AstraZeneca Daily ETC      UK
# 3017   AZN.LSE    AZN                               AstraZeneca PLC      UK
#
#      exchange currency          type          isin
# 27        LSE      USD  Common Stock
# 2609      LSE      GBX           ETF  XS2066793444
# 3017      LSE      GBX  Common Stock  GB0009895292

# %% [markdown]
# The default response format is DataFrame but it's possible to have it in json with `response_format`.

# %%
ok.search("Pfizer", namespace="US", response_format="json")
# Out:
# '[{"symbol":"PFE.US","ticker":"PFE","name":"Pfizer Inc","country":"USA","exchange":"NYSE","currency":"USD","type":"Common Stock","isin":"US7170811035"}]'

# %% [markdown]
# DataFrame obtained with `symbols_in_namespace` can be used for more complex queries.
# For instance, if it's necessary find only a certain type of securities. Let's get a list of ETF in Frankfurt Stock Exchange.

# %%
sb = ok.symbols_in_namespace("XFRA")
sb[sb["type"] == "ETF"]
# Out:
#           symbol ticker                                               name  \
# 6      00XL.XFRA   00XL               WisdomTree Copper - EUR Daily Hedged
# 431    10AI.XFRA   10AI  Amundi Index Solutions - Amundi Index MSCI Europe
# 432    10AJ.XFRA   10AJ  Amundi Index Solutions - Amundi Index FTSE EPR...
# 433    10AK.XFRA   10AK  Amundi Index Solutions - Amundi Index J.P. Mor...
# 434    10AL.XFRA   10AL  Amundi Index Solutions - Amundi Index Bofa Mer...
# ...          ...    ...                                                ...
# 13089  ZPRV.XFRA   ZPRV  SSgA SPDR ETFs Europe II Public Limited Compan...
# 13090  ZPRW.XFRA   ZPRW          SPDR® MSCI Europe Value UCITS ETF EUR Acc
# 13091  ZPRX.XFRA   ZPRX  SSgA SPDR ETFs Europe II Public Limited Compan...
# 13098  ZSRI.XFRA   ZSRI  BNP Paribas Easy - MSCI Europe SRI S-Series 5%...
# 13099  ZSRM.XFRA   ZSRM  BNP Paribas Easy MSCI USA SRI S-Series PAB 5% ...
#
#        country exchange currency type          isin
# 6      Germany     XFRA      EUR  ETF  DE000A1NZLL0
# 431    Germany     XFRA      EUR  ETF  LU1737652310
# 432    Germany     XFRA      EUR  ETF  LU1737652823
# 433    Germany     XFRA      EUR  ETF  LU1737653631
# 434    Germany     XFRA      EUR  ETF  LU1737653714
# ...        ...      ...      ...  ...           ...
# 13089  Germany     XFRA      EUR  ETF  IE00BSPLC413
# 13090  Germany     XFRA      EUR  ETF  IE00BSPLC306
# 13091  Germany     XFRA      EUR  ETF  IE00BSPLC298
# 13098  Germany     XFRA      EUR  ETF  LU1753045415
# 13099  Germany     XFRA      EUR  ETF  LU1659681586
#
# [1351 rows x 8 columns]
