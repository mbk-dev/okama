# %% [markdown]
# <a href="https://colab.research.google.com/github/mbk-dev/okama/blob/master/examples/05%20efficient%20frontier%20multi-period.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12.0, 6.0]

import okama as ok

# %% [markdown]
# A single period approach is used in classic Markowitz Mean-Variance Analysis (MVA) where a portfolio is always rebalanced and has original weights. In `okama` it's equivalent to monthly rebalanced portfolios as monthly historical data is used.

# %% [markdown]
# However, in real life portfolios are not rebalanced every day or every moth. In **multi-period** approach portfolio is rebalanced to the original allocation with a certain frequency (annually, quarterly etc.) or not rebalanced at all.

# %% [markdown]
# **EfficientFrontierReb** class can be used for multi-period optimization. Actually two rebalancing frequencies can be usd (**reb_period** parameter):
# - 'year' - one Year (default)
# - 'none' - not rebalanced portfolios

# %% [markdown]
# ## 2 Assets

# %% [markdown]
# First example is a simple USD portfolio with 2 ETFs (S&P500 and physical gold spot prices).

# %%
ls = ['SPY.US', 'GLD.US']
curr = 'USD'
y = ok.EfficientFrontierReb(assets=ls, 
                            first_date='2004-12',  # optionally we can chouse first and last dates in the histrorical data
                            last_date='2020-10', 
                            ccy=curr,  
                            reb_period='year',  # set rebalancing period to one year
                            ticker_names=True,  # use tickers in DataFrame column names (coluld be set to False to show full assets names instead tickers)
                            n_points=20,  # number of points in the Efficient Frontier
                            verbose=True)  # verbose mode is ON to show progress while the EF points are calcualted

# %%
y
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\envs\py39\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\Anaconda3\envs\py39\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\Anaconda3\envs\py39\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# c:\users\sergey\onedrive\notebooks\okama\okama\frontier\multi_period.py in __repr__(self)
#      46         dic = {
#      47             'symbols': self.symbols,
# ---> 48             'currency': self.currency.ticker,
#      49             'first date': self.first_date.strftime("%Y-%m"),
#      50             'last_date': self.last_date.strftime("%Y-%m"),
#
# AttributeError: 'str' object has no attribute 'ticker'

# %%
y.names
# Out:
# {'SPY.US': 'SPDR S&P 500 ETF Trust', 'GLD.US': 'SPDR Gold Shares'}

# %% [markdown]
# We need to get all the points of the optimized portfolios to plot the Efficient Frontier.
#
# As the algorithm uses "black box" objective function (there is no algebraic functions as in classic MVA) the optimization process is slower than in single period optimization.
# Using "verbose mode" is recommended to see the progress.

# %%
df_reb_year = y.ef_points
# Out:
# left EF point #1/20 is done in 0.73 sec.
# left EF point #2/20 is done in 1.68 sec.
# left EF point #3/20 is done in 1.54 sec.
# left EF point #4/20 is done in 1.47 sec.
# left EF point #5/20 is done in 1.62 sec.
# left EF point #6/20 is done in 1.59 sec.
# left EF point #7/20 is done in 1.76 sec.
# left EF point #8/20 is done in 1.99 sec.
# left EF point #9/20 is done in 1.85 sec.
# left EF point #10/20 is done in 4.13 sec.
# left EF point #11/20 is done in 1.90 sec.
# left EF point #12/20 is done in 1.90 sec.
# left EF point #13/20 is done in 2.44 sec.
# left EF point #14/20 is done in 2.13 sec.
# left EF point #15/20 is done in 1.69 sec.
# left EF point #16/20 is done in 1.89 sec.
# left EF point #17/20 is done in 2.04 sec.
# left EF point #18/20 is done in 1.77 sec.
# left EF point #19/20 is done in 1.72 sec.
# left EF point #20/20 is done in 4.53 sec.
# right EF point #1/16 is done in 2.75 sec.
# right EF point #2/16 is done in 2.45 sec.
# right EF point #3/16 is done in 2.38 sec.
# right EF point #4/16 is done in 2.83 sec.
# right EF point #5/16 is done in 2.77 sec.
# right EF point #6/16 is done in 5.37 sec.
# right EF point #7/16 is done in 3.05 sec.
# right EF point #8/16 is done in 2.87 sec.
# right EF point #9/16 is done in 3.01 sec.
# right EF point #10/16 is done in 2.19 sec.
# right EF point #11/16 is done in 2.36 sec.
# right EF point #12/16 is done in 2.55 sec.
# right EF point #13/16 is done in 2.25 sec.
# right EF point #14/16 is done in 1.78 sec.
# right EF point #15/16 is done in 2.12 sec.
# right EF point #16/16 is done in 1.21 sec.
# Total time taken is 1.43 min.

# %% [markdown]
# **ef_points** property returns the dataframe (table).
# Each row has risk and return properties of portfolio which could be used to plot the points of the frontier:
# - _Risk_ - the volatility or annual standard deviation
# - _CAGR_ - Compound annual growth rate
# ... and assets weights

# %%
df_reb_year.head(5)
# Out:
#        Risk      CAGR    GLD.US    SPY.US
# 0  0.159400  0.087763  0.000000  1.000000
# 1  0.157205  0.088171  0.014261  0.985739
# 2  0.155007  0.088580  0.028941  0.971059
# 3  0.152810  0.088988  0.044079  0.955921
# 4  0.150615  0.089397  0.059713  0.940287

# %% [markdown]
# It's interesting to compare annualy rebalanced portfolios with not rebalanced portfolios.

# %%
y.reb_period = 'none'  # Set rebalancing period to NONE

# %%
df_not_reb = y.ef_points
# Out:
# left EF point #1/20 is done in 0.08 sec.
# left EF point #2/20 is done in 0.19 sec.
# left EF point #3/20 is done in 0.11 sec.
# left EF point #4/20 is done in 0.12 sec.
# left EF point #5/20 is done in 0.08 sec.
# left EF point #6/20 is done in 0.16 sec.
# left EF point #7/20 is done in 0.21 sec.
# left EF point #8/20 is done in 0.11 sec.
# left EF point #9/20 is done in 0.12 sec.
# left EF point #10/20 is done in 0.13 sec.
# left EF point #11/20 is done in 0.11 sec.
# left EF point #12/20 is done in 0.14 sec.
# left EF point #13/20 is done in 0.25 sec.
# left EF point #14/20 is done in 0.12 sec.
# left EF point #15/20 is done in 0.14 sec.
# left EF point #16/20 is done in 0.12 sec.
# left EF point #17/20 is done in 0.11 sec.
# left EF point #18/20 is done in 0.13 sec.
# left EF point #19/20 is done in 0.12 sec.
# left EF point #20/20 is done in 0.13 sec.
# Total time taken is 0.05 min.

# %% [markdown]
# Finally we can plot both Efficient Frontiers...

# %%
fig = plt.figure(figsize=(12,6))
fig.subplots_adjust(bottom=0.2, top=1.5)
ok.Plots(ls, ccy=curr, first_date='2004-12', last_date='2020-10').plot_assets(kind='cagr')  # should be the same history period and the currency
ax = plt.gca()
ax.plot(df_reb_year.Risk, df_reb_year.CAGR, label='Annually rebalanced')
ax.plot(df_not_reb.Risk, df_not_reb.CAGR, label='Not rebalanced')
ax.set_xlabel('Risk (Standard Deviation)')
ax.set_ylabel('CAGR')
ax.legend();

# %% [markdown]
# As one can see rebalanced portfolios have more options with higher CAGR. The difference is up to 0,5%.

# %% [markdown]
# ### Multiple assets

# %% [markdown]
# Second example will have an asset list composed by US ETFs and Russian indexes for bonds (RGBITR.INDX) and stocks (MCFTR.INDX).
# The currency of portfolios is Russian Ruble (RUB).

# %%
ls_m = ['SPY.US', 'GLD.US', 'PGJ.US', 'RGBITR.INDX', 'MCFTR.INDX']
curr_rub = 'RUB'

# %%
x = ok.EfficientFrontierReb(assets=ls_m,
                            first_date='2005-01',
                            last_date='2020-11',
                            ccy=curr_rub,
                            reb_period='year',  # set rebalancing period to one year
                            n_points=20,
                            verbose=True
                           )

# %%
x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\envs\py39\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\Anaconda3\envs\py39\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\Anaconda3\envs\py39\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# c:\users\sergey\onedrive\notebooks\okama\okama\frontier\multi_period.py in __repr__(self)
#      46         dic = {
#      47             'symbols': self.symbols,
# ---> 48             'currency': self.currency.ticker,
#      49             'first date': self.first_date.strftime("%Y-%m"),
#      50             'last_date': self.last_date.strftime("%Y-%m"),
#
# AttributeError: 'str' object has no attribute 'ticker'

# %%
x.names
# Out:
# {'SPY.US': 'SPDR S&P 500 ETF Trust',
#  'GLD.US': 'SPDR Gold Shares',
#  'PGJ.US': 'Invesco Golden Dragon China ETF',
#  'RGBITR.INDX': 'Russian Government Bond Index',
#  'MCFTR.INDX': 'MOEX Total Return'}

# %% [markdown]
# As in the first example we will draw 2 Efficient Frontier: not rebalanced portfolios and with annually rebalanced portfolios..

# %%
df1_reb_year = x.ef_points
# Out:
# left EF point #1/20 is done in 1.39 sec.
# left EF point #2/20 is done in 4.63 sec.
# left EF point #3/20 is done in 3.74 sec.
# left EF point #4/20 is done in 3.13 sec.
# left EF point #5/20 is done in 2.70 sec.
# left EF point #6/20 is done in 3.23 sec.
# left EF point #7/20 is done in 3.99 sec.
# left EF point #8/20 is done in 5.84 sec.
# left EF point #9/20 is done in 4.81 sec.
# left EF point #10/20 is done in 4.22 sec.
# left EF point #11/20 is done in 5.35 sec.
# left EF point #12/20 is done in 4.49 sec.
# left EF point #13/20 is done in 4.69 sec.
# left EF point #14/20 is done in 4.57 sec.
# left EF point #15/20 is done in 4.76 sec.
# left EF point #16/20 is done in 5.09 sec.
# left EF point #17/20 is done in 4.59 sec.
# left EF point #18/20 is done in 4.47 sec.
# left EF point #19/20 is done in 5.48 sec.
# left EF point #20/20 is done in 12.59 sec.
# right EF point #1/4 is done in 7.31 sec.
# right EF point #2/4 is done in 8.61 sec.
# right EF point #3/4 is done in 7.23 sec.
# right EF point #4/4 is done in 4.12 sec.
# Total time taken is 2.33 min.

# %%
x.reb_period = 'none'

# %%
df1_not_reb = x.ef_points
# Out:
# left EF point #1/20 is done in 0.14 sec.
# left EF point #2/20 is done in 0.20 sec.
# left EF point #3/20 is done in 0.30 sec.
# left EF point #4/20 is done in 0.29 sec.
# left EF point #5/20 is done in 0.37 sec.
# left EF point #6/20 is done in 0.33 sec.
# left EF point #7/20 is done in 0.30 sec.
# left EF point #8/20 is done in 0.35 sec.
# left EF point #9/20 is done in 0.34 sec.
# left EF point #10/20 is done in 0.41 sec.
# left EF point #11/20 is done in 0.44 sec.
# left EF point #12/20 is done in 0.47 sec.
# left EF point #13/20 is done in 0.45 sec.
# left EF point #14/20 is done in 0.40 sec.
# left EF point #15/20 is done in 0.49 sec.
# left EF point #16/20 is done in 0.47 sec.
# left EF point #17/20 is done in 0.52 sec.
# left EF point #18/20 is done in 0.41 sec.
# left EF point #19/20 is done in 0.34 sec.
# left EF point #20/20 is done in 0.24 sec.
# Total time taken is 0.12 min.

# %%
fig = plt.figure(figsize=(12,6))
fig.subplots_adjust(bottom=0.2, top=1.5)
ok.Plots(ls_m, ccy=curr_rub, first_date='2005-01', last_date='2020-11').plot_assets(kind='cagr')  # should be the same history period and the currency
ax = plt.gca()
ax.plot(df1_reb_year.Risk, df1_reb_year.CAGR, label='Annually rebalanced')
ax.plot(df1_not_reb.Risk, df1_not_reb.CAGR, label='Not rebalanced')
ax.set_xlabel('Risk (Standard Deviation)')
ax.set_ylabel('CAGR')
ax.legend();

# %% [markdown]
# ### Compare with monthly rebalanced portfolios

# %% [markdown]
# We can also add monthly rebalanced portfolio Frontier (single period optimization) to the chart.

# %% [markdown]
# Single period optimization can be achieved with **EfficientFrontier** class.

# %%
z = ok.EfficientFrontier(assets=ls_m,
                         first_date='2005-01',
                         last_date='2020-11',
                         ccy=curr_rub,
                         n_points=20,
                        )

# %%
df2 = z.ef_points  # Create EF points

# %%
fig = plt.figure(figsize=(12,6))
fig.subplots_adjust(bottom=0.2, top=1.5)
ok.Plots(ls_m, ccy=curr_rub, first_date='2005-01', last_date='2020-11').plot_assets(kind='cagr')  # should be the same history period and the currency
ax = plt.gca()
ax.plot(df1_reb_year.Risk, df1_reb_year.CAGR, label='Annually rebalanced')
ax.plot(df2.Risk, df2.CAGR, linestyle='--', label='Monthly rebalanced')
ax.plot(df1_not_reb.Risk, df1_not_reb.CAGR, label='Not rebalanced')
ax.set_xlabel('Risk (Standard Deviation)')
ax.set_ylabel('CAGR')
ax.legend();

# %% [markdown]
# ### Monte Carlo simulation for multi-period optimization

# %% [markdown]
# As in the EfficientFrontier there is a **get_monte_carlo** method which allows to generate N random multi-period portfolios for selected rebalancing frequency.

# %%
x.reb_period = 'year'  # me must set the rebalancing frequency first (annually rebalanced portfolios in this case)

# %%
monte_carlo = x.get_monte_carlo(n=1000)  # generate n random portfolios

# %%
monte_carlo.head(5)  # table of random portfolios properties
# Out:
#        CAGR      Risk
# 0  0.170291  0.142103
# 1  0.160637  0.127142
# 2  0.176518  0.161678
# 3  0.164563  0.123436
# 4  0.182337  0.179048

# %%
fig = plt.figure(figsize=(12,6))
fig.subplots_adjust(bottom=0.2, top=1.5)
ok.Plots(ls_m, ccy=curr_rub, first_date='2005-01', last_date='2020-11').plot_assets(kind='cagr')  # should be the same history period and the currency
ax = plt.gca()
ax.plot(df1_reb_year.Risk, df1_reb_year.CAGR)
ax.scatter(monte_carlo.Risk, monte_carlo.CAGR)  # draw the random portfolios points
ax.set_xlabel('Risk (Standard Deviation)')
ax.set_ylabel('CAGR');

# %% [markdown]
# To cover more space inside the Efficient Frontier with Monte Carlos simulation bigger number on random portfolios is required. But it will take more time to generate it.
