# %% [markdown]
# <a href="https://colab.research.google.com/github/mbk-dev/okama/blob/master/examples/08%20backtesting%20distribution.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %%
# %%capture --no-stderr
# %pip install --quiet -U okama

# %%
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [12.0, 6.0]

import okama as ok

# %% [markdown]
# Sometimes it is useful to examine the distribution of asset returns and compare it with the normal distribution.
# **It is important to backtest a distribution before using it in forecasting models.**

# %% [markdown]
# ### Skewness

# %% [markdown]
# Skewness is a measure of symmetry.
# For normally distributed data, the skewness should be about zero.
# A skewness value greater than zero means that there is more weight in the right tail of the distribution.

# %% [markdown]
# **List of Assets**

# %% [markdown]
# Let's verify skewness for different types of assets:
# - S&P 500 TR index
# - US real estate ETF (VNQ)
# - gold spot prices
# - USD to EUR exchange rate

# %%
ls = ["SP500TR.INDX", "VNQ.US", "GC.COMM", "USDEUR.FX"]

# %%
al = ok.AssetList(ls, inflation=False)  # iflation set to False as we don't need to compare the returns to indflation.
al
# Out:
# assets           [SP500TR.INDX, VNQ.US, GC.COMM, USDEUR.FX]
# currency                                                USD
# first_date                                          2004-10
# last_date                                           2026-02
# period_length                            21 years, 5 months
# inflation                                              None
# dtype: object

# %%
al.names
# Out:
# {'SP500TR.INDX': 'S&P 500 TR (Total Return)',
#  'VNQ.US': 'Vanguard Real Estate Index Fund ETF Shares',
#  'GC.COMM': 'Gold (COMEX)',
#  'USDEUR.FX': 'US Dollar/Euro FX Cross Rate'}

# %% [markdown]
# Before we look at the skewness of each asset, we can visualize the distribution shapes with histograms.

# %%
al.assets_ror.hist(bins=25);

# %% [markdown]
# Let's verify the expanding (accumulated) skewness.

# %%
al.skewness.plot();

# %% [markdown]
# The chart shows that all distributions have negative skewness. Only gold spot prices (GC.COMM) show skewness close to zero.

# %%
al.skewness.iloc[-1]  # last values
# Out:
# Symbols
# SP500TR.INDX   -0.623960
# VNQ.US         -0.640344
# GC.COMM        -0.015107
# USDEUR.FX       0.371024
# Name: 2026-02, dtype: float64

# %% [markdown]
# We can also check rolling skewness. It is useful for seeing how this parameter changes over time.

# %%
al.skewness_rolling(window=12 * 5).plot();

# %% [markdown]
# **Portfolio**

# %% [markdown]
# Skewness can also be calculated for a portfolio return series.
# Let's build a classic 60/40 stock/bond portfolio using Vanguard's oldest index mutual funds.

# %%
weights = [0.6, 0.4]
funds = ["VFINX.US", "VBMFX.US"]

# %%
pf = ok.Portfolio(funds, weights=weights, inflation=False)
pf
# Out:
# symbol                          portfolio_4848.PF
# assets                       [VFINX.US, VBMFX.US]
# weights                                [0.6, 0.4]
# rebalancing_period                          month
# rebalancing_abs_deviation                    None
# rebalancing_rel_deviation                    None
# currency                                      USD
# inflation                                    None
# first_date                                1987-01
# last_date                                 2026-02
# period_length                  39 years, 2 months
# dtype: object

# %%
pf.names
# Out:
# {'VFINX.US': 'VANGUARD 500 INDEX FUND INVESTOR SHARES',
#  'VBMFX.US': 'VANGUARD TOTAL BOND MARKET INDEX FUND INVESTOR SHARES'}

# %% [markdown]
# It's possible to visualize the historical distribution and verify how it fits the theoretical distribution.

# %%
pf.dcf.mc.plot_hist_fit(bins=25);

# %%
pf.dcf.mc.skewness.plot();

# %% [markdown]
# It is interesting to see how portfolio skewness gradually became slightly negative over time. The sharpest declines in skewness occurred around 2000 (the dot-com bust) and 2008 (the global financial crisis).

# %%
pf.dcf.mc.skewness_rolling(window=12 * 10).plot();

# %% [markdown]
# However, in the rolling 10-year skewness chart, we see skewness increasing in 2019.

# %% [markdown]
# ### Kurtosis

# %% [markdown]
# Kurtosis is a measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution.
# It should be close to zero for normal distribution (*okama* uses Fisher normalized kurtosis).
# The heavy (fat) tails mean that extreme events occur more frequently in reality than what a normal distribution would predict.

# %%
al.kurtosis.plot();

# %%
al.kurtosis.iloc[-1]  # last values
# Out:
# Symbols
# SP500TR.INDX    1.380330
# VNQ.US          5.465536
# GC.COMM         0.646650
# USDEUR.FX       3.251482
# Name: 2026-02, dtype: float64

# %% [markdown]
# We see that gold spot price returns are close to a normal distribution. S&P 500 returns also have relatively low *kurtosis*, whereas the other assets are clearly farther from normal (especially USDEUR).

# %%
al.kurtosis_rolling(window=12 * 5).plot();

# %% [markdown]
# Rolling kurtosis with 4 years window confirms this conclusion.

# %% [markdown]
# It is also interesting to examine *kurtosis* for the classic 60/40 portfolio.

# %%
pf.dcf.mc.kurtosis.plot();

# %%
pf.dcf.mc.kurtosis_rolling(12 * 20).plot();

# %% [markdown]
# Across all charts, the classic portfolio has kurtosis only slightly different from zero.

# %% [markdown]
# ### Jarque-Bera test for Normality

# %% [markdown]
# Jarque-Bera is a popular test for normality based on *skewness* and *kurtosis*.
# It shows whether returns have skewness and kurtosis consistent with a normal distribution (the null hypothesis, H0).
#
# The test returns the *statistic* (first row) and the *p-value* (second row).
# The *p-value* is the probability of obtaining a result at least this extreme under the assumption that the null hypothesis is true.
# In general, a large Jarque-Bera statistic and a very small **p-value** indicate that the null hypothesis should be rejected and the time series is not normally distributed.
#
# A 5% threshold can be used as a simple rule of thumb for the **p-value**.

# %%
al.jarque_bera
# Out:
# Symbols    SP500TR.INDX        VNQ.US   GC.COMM     USDEUR.FX
# statistic  3.543409e+01  3.223159e+02  4.005765  1.131166e+02
# p-value    2.021084e-08  1.023293e-70  0.134946  2.735562e-25

# %% [markdown]
# In the Jarque-Bera results for the asset list, only gold (GC.COMM) has a sufficiently high **p-value**, so H0 is not rejected for that series.

# %%
pf.dcf.mc.jarque_bera
# Out:
# {'statistic': np.float64(81.20711097167442),
#  'p-value': np.float64(2.3232711895312694e-18)}

# %% [markdown]
# According to the Jarque-Bera test, the null hypothesis is rejected for the classic 60/40 portfolio.

# %% [markdown]
# ### Kolmogorov-Smirnov test

# %% [markdown]
# #### Normal distribution

# %% [markdown]
# In *okama*, the one-sample Kolmogorov-Smirnov test is used to check whether data follow a given distribution. We can test whether return series fit normal or lognormal distributions well enough.
#
# Like the Jarque-Bera test, it returns the *statistic* (first row) and the *p-value* (second row). The null hypothesis, that the observed and theoretical distributions are similar, is not rejected when the *p-value* is high enough. A 5% threshold can be used as a rule of thumb.

# %%
al.kstest(distr="norm")
# Out:
#            SP500TR.INDX    VNQ.US   GC.COMM     USDEUR.FX
# statistic      0.091842  0.077924  0.038492  1.778767e-01
# p-value        0.024523  0.083612  0.826517  1.386116e-07

# %% [markdown]
# H0 is not rejected for gold (GC.COMM) and Real Estate ETF (VNQ.US). Relatively close to 5% threshold is S&P 500.

# %%
pf.dcf.mc.kstest
# Out:
# {'statistic': np.float64(0.07220051177741926),
#  'p-value': np.float64(0.014142629143832726)}

# %% [markdown]
# For the 60/40 portfolio, the Kolmogorov-Smirnov test shows a 6.5% p-value, which is acceptable under a 5% threshold.

# %% [markdown]
# #### Lognormal distribution

# %% [markdown]
# The Kolmogorov-Smirnov test can also be used to evaluate the goodness of fit of a **lognormal** distribution.

# %%
al.kstest(distr="lognorm")
# Out:
#            SP500TR.INDX    VNQ.US   GC.COMM     USDEUR.FX
# statistic      0.101074  0.092247  0.031257  1.769906e-01
# p-value        0.009728  0.023591  0.956480  1.633809e-07

# %% [markdown]
# We see that the p-value for gold (GC.COMM) is higher under the lognormal distribution.

# %%
pf.dcf.mc.kstest
# Out:
# {'statistic': np.float64(0.07220051177741926),
#  'p-value': np.float64(0.014142629143832726)}

# %% [markdown]
# According to Kolmogorov-Smirnov test 60/40 portfolio distribution is closer to normal.

# %% [markdown]
# ## Finding the best-fitting distribution

# %% [markdown]
# The Monte Carlo class includes the `kstest_for_all_distributions` method, which performs the Kolmogorov-Smirnov test for all available distribution types.

# %%
pf.dcf.mc.kstest_for_all_distributions
# Out:
#          statistic   p-value
# norm      0.072201  0.014143
# lognorm   0.078058  0.006149
# t         0.036929  0.530909

# %% [markdown]
# The most suitable distribution can be identified by the highest p-value.

# %% [markdown]
# ## Tuning parameters for Student's t distribution

# %%
pf.dcf.mc.distribution = "t"

# %%
pf.dcf.mc
# Out:
# Portfolio symbol                            portfolio_4848.PF
# Monte Carlo distribution                                    t
# Distribution parameters                                  None
# Distribution parameters after resolving    (5.63, 0.01, 0.02)
# Monte Carlo period                                         25
# Monte Carlo number                                        100
# dtype: object

# %% [markdown]
# Parameters for Student's t distribution are determined automatically (as for other distributions), but they are fitted using historical data across all percentiles. Since there are more historical observations around the median, the automatically selected parameters are better suited for forecasts near the center of the distribution.

# %% [markdown]
# It is possible to automatically optimize the parameters of Student's t distribution for forecasting at a specific percentile.

# %% [markdown]
# For this, use the `optimize_df_for_students` method. Let's find the most suitable degrees of freedom value for forecasting at the 5th percentile.

# %%
pf.dcf.mc.optimize_df_for_students(var_level=5)
# Out:
# 4.260007759068121

# %% [markdown]
# Next, we can assign the degrees of freedom value we found and leave the other distribution parameters unchanged.

# %%
pf.dcf.mc.distribution_parameters = (4.26, None, None)  # df, loc, scale

# %%
pf.dcf.mc.get_parameters_for_distribution()
# Out:
# (4.26, 0.00897294143134228, 0.02228875486157926)

# %% [markdown]
# ### Q-Q or Quantile-Quantile Plot

# %% [markdown]
# Finally, it is useful to see how close the percentiles (quantiles) of historical data are to a theoretical distribution with `plot_percentiles_fit` (available for `Portfolio`).

# %%
pf.dcf.mc.plot_qq(var_level=5)  # var_level sets the confidence level in percent for VaR and CVaR.
# Out:
# 2026-02-23 17:52:58,153 - INFO - VaR  5%: theor=-0.037699, emp=-0.040425, delta(emp-theor)=-0.002726
# 2026-02-23 17:52:58,153 - INFO - CVAR 5%: theor=-0.049197, emp=-0.059157, delta(emp-theor)=-0.009960
# 2026-02-23 17:52:58,153 - INFO - 95% CI empiric VaR (bootstrap): [-0.047100, -0.033554]
# 2026-02-23 17:52:58,154 - INFO - 95% CI empiric CVaR (bootstrap): [-0.070158, -0.047982]

# %% [markdown]
# The chart also shows bootstrap bands. In a Q-Q plot, bootstrap bands are confidence envelopes around the quantiles that illustrate the amount of random sample-to-sample variation one would expect. They are built by repeatedly resampling a dataset of the same size and recomputing the Q-Q points.
